# %%
import pandas as pd
from src import *
allimages = pd.read_csv("Tables/All_Subjects_All_Images_20Feb2026.csv")
diagnosis = pd.read_csv("Tables/All_Subjects_DXSUM_20Feb2026.csv")

# %%
# Load table of all images
allimages = pd.read_csv("Tables/All_Subjects_All_Images_20Feb2026.csv")

# %%
# Print total number of images
len(allimages[allimages.modality=="MRI"])
# Out:
# 230002

# %%
# Info of all MRI images
mris = allimages[
    (allimages.modality=="MRI")&
    (allimages.image_type=="Original")
    ]

# %%
# Print top 50 frequent MRI image descriptions
mris.image_description.value_counts()[:50]
# Out:
# image_description
# 3 Plane Localizer                      12014
# localizer                               7604
# Axial 3D ME T2 GRE (MSV21)              7183
# 3-plane localizer                       5823
# MPRAGE                                  5558
# Field Mapping                           5522
# Axial PD-T2 TSE                         3942
# Axial PD/T2 FSE                         3822
# Localizer                               3288
# Axial T2-FLAIR                          3041
# Axial T2 Star                           2370
# Sagittal 3D FLAIR                       2324
# Axial 3TE T2 STAR                       2256
# AXIAL_T2_STAR                           2075
# MPRAGE GRAPPA2                          2061
# MP-RAGE                                 2037
# MPRAGE Repeat                           1961
# B1-calibration Body                     1897
# B1-calibration Head                     1866
# MP-RAGE REPEAT                          1669
# HighResHippo                            1487
# B1-Calibration Body                     1479
# B1-Calibration PA                       1461
# Accelerated Sagittal MPRAGE             1445
# HighResHippocampus                      1417
# Calibration Scan                        1338
# Field_mapping                           1221
# Axial FLAIR                             1101
# Sagittal 3D FLAIR (MSV22)                999
# Accelerated Sagittal MPRAGE (MSV21)      948
# Axial T2 TSE with Fat Sat                939
# SURVEY                                   898
# Axial T2-Star                            871
# Head,3-P,2D,LOCALIZER                    870
# HighResHippocampus (MSV21)               858
# MPRAGE SENSE2                            856
# Sagittal 3D T2 SPACE (MSV21)             793
# Double_TSE                               711
# Sag IR-SPGR                              689
# Accelerated Sag IR-FSPGR                 683
# LOC                                      669
# ADNI_gre_field_mapping                   667
# FSE PD/T2                                602
# Axial Field Mapping                      570
# Circle Scout                             550
# Axial T2 STAR                            543
# Sag IR-FSPGR                             430
# 3-pl T2* FGRE                            414
# Accelerated SAG IR-SPGR                  414
# Isotropic image                          410
# Name: count, dtype: int64

# %%
# MRIs from ADNI 3 and 4
mris_adni34 = mris[(mris.phase=="ADNI 3")|(mris.phase=="ADNI 4")]
len(mris_adni34)
# Out:
# 37622

# %%
# Load table of diagnosis
diagnosis = pd.read_csv("Tables/All_Subjects_DXSUM_20Feb2026.csv")
diagnosis.USERDATE = diagnosis.USERDATE.apply(pd.to_datetime)

# %%
# Per phase diagnosis
diagnosis_phase = {}
for i in [1,"GO",2,3,4]:
    diagnosis_phase[i] = diagnosis[diagnosis.PHASE==f"ADNI{i}"]

# %%
# Print counts of patients in each phase
for i in [1,"GO",2,3,4]:
    print(f"Count of patients in phase {i}: {diagnosis_phase[i].PTID.nunique()}")

p = [1,"GO",2,3,4]
for i in range(4):
    print(f"Count of patients in phase {p[i]} that didn't continue in phase {p[i+1]}: {diagnosis_phase[p[i]][~diagnosis_phase[p[i]].PTID.isin(diagnosis_phase[p[i+1]].PTID)].PTID.nunique()}")
# Out:
# Count of patients in phase 1: 819
# Count of patients in phase GO: 338
# Count of patients in phase 2: 1438
# Count of patients in phase 3: 1376
# Count of patients in phase 4: 1339
# Count of patients in phase 1 that didn't continue in phase GO: 610
# Count of patients in phase GO that didn't continue in phase 2: 41
# Count of patients in phase 2 that didn't continue in phase 3: 1028
# Count of patients in phase 3 that didn't continue in phase 4: 860

# %%
# Total number of unique patients
diagnosis.PTID.nunique()
# Out:
# 3789

# %%
allimages3 = allimages[(allimages.phase=="ADNI 3")&(allimages.modality=="MRI")]

# %%
cn = diagnosis[diagnosis.DIAGNOSIS==1.0][["PTID","USERDATE","DIAGNOSIS"]]
mci = diagnosis[diagnosis.DIAGNOSIS==2.0][["PTID","USERDATE","DIAGNOSIS"]]
ad = diagnosis[diagnosis.DIAGNOSIS==3.0][["PTID","USERDATE","DIAGNOSIS"]]

# %%
#### Transition patients
patients = pd.merge(cn,ad,on="PTID")
times = patients.groupby("PTID")["USERDATE_y"].max()-patients.groupby("PTID")["USERDATE_x"].min()
cleaned_times = times[times>pd.Timedelta(0)]
len(cleaned_times)

### No transition patients:
# patients = mci[(~mci.PTID.isin(cn.PTID))&(~mci.PTID.isin(ad.PTID))]
# times = patients.groupby("PTID")["USERDATE"].max()-patients.groupby("PTID")["USERDATE"].min()
# cleaned_times = times
# times
# Out:
# 52

# %%
visits = allimages3[allimages3.subject_id.isin(cleaned_times.index)]

# %%
# Average number of visits
visits.groupby("subject_id")["image_date"].unique().apply(len).mean()
# Out:
# np.float64(3.2264150943396226)

# %%
# Average duration
times.mean()
# Out:
# Timedelta('1133 days 20:08:34.285714')

# %%
# All t1w images
mris_t1w = mris[
    mris.image_description.str.contains("RAGE")|
    mris.image_description.str.contains("SPGR")
    ]
len(mris_t1w)
# Out:
# 23875

# %%
mris_t1w.image_description.value_counts()[:20]
# Out:
# image_description
# MPRAGE                                 5558
# MPRAGE GRAPPA2                         2061
# MP-RAGE                                2037
# MPRAGE Repeat                          1961
# MP-RAGE REPEAT                         1669
# Accelerated Sagittal MPRAGE            1445
# Accelerated Sagittal MPRAGE (MSV21)     948
# MPRAGE SENSE2                           856
# Sag IR-SPGR                             689
# Accelerated Sag IR-FSPGR                683
# Sag IR-FSPGR                            430
# Accelerated SAG IR-SPGR                 414
# Sagittal 3D Accelerated MPRAGE          355
# MPRAGE_GRAPPA2                          334
# Accelerated Sag IR-SPGR                 280
# MP-RAGE-Repeat                          268
# Accelerated Sagittal IR-FSPGR           258
# Accelerated Sagittal MPRAGE_ND          258
# IR-FSPGR-Repeat                         164
# IR-FSPGR                                154
# Name: count, dtype: int64

# %%
# All T1w images in ADNI 3&4

mris_34_t1w = mris_adni34[
    mris_adni34.image_description.str.contains("RAGE")|
    mris_adni34.image_description.str.contains("SPGR")
    ]
len(mris_34_t1w)
# Out:
# 4199

# %%
# Number of unique patients with T1w in ADNI 3&4

mris_34_t1w.subject_id.nunique()
# Out:
# 1796

# %%
mris_34_t1w.image_date = mris_34_t1w.image_date.apply(pd.to_datetime)
span_counts34 = mris_34_t1w.groupby("subject_id")["image_date"].agg(lambda x:x.max()-x.min())

# %%
# Number of patients in ADNI 3&4 with duration > 3 years
len(span_counts34[span_counts34>pd.Timedelta("1056 days")])
# Out:
# 504

# %%
mris_t1w.image_date = mris_t1w.image_date.apply(pd.to_datetime)
span_counts = mris_t1w.groupby("subject_id")["image_date"].agg(lambda x:x.max()-x.min())

# %%
# Number of patients with duration > 1 years
len(span_counts[span_counts>pd.Timedelta("365 days")])
# Out:
# 2056

# %%
biomark = pd.read_csv("Tables/All_Subjects_BIOMARK_20Feb2026.csv",low_memory=False)

# %%
biomark.update_stamp = biomark.update_stamp.apply(pd.to_datetime)
biomark_span = biomark.groupby("PTID")["update_stamp"].agg(lambda x:x.max()-x.min())

# %%
len(biomark_span[biomark_span>pd.Timedelta("360 days")])
# Out:
# 1929

# %%
biomark_adni34 = biomark[
    (biomark.PHASE=="ADNI3")|
    (biomark.PHASE=="ADNI4")
    ]

# %%
biomark_adni34.update_stamp = biomark_adni34.update_stamp.apply(pd.to_datetime)
biomark_adni34_span = biomark_adni34.groupby("PTID")["update_stamp"].agg(lambda x:x.max()-x.min())

# %%
len(biomark_adni34_span[biomark_adni34_span>pd.Timedelta("365 days")])
# Out:
# 803

# %%
merged = pd.merge(biomark_adni34_span,span_counts34,left_on="PTID",right_on="subject_id")

# %%
len(merged)
# Out:
# 1581

# %%
t = pd.Timedelta("1095 days")
len(merged[(merged.update_stamp>t)&(merged.image_date>t)])
# Out:
# 443

# %%
# Study the following tables
dti = pd.read_csv("Tables/All_Subjects_DTIROI_MEAN_20Feb2026.csv")
robust = pd.read_csv("Tables/All_Subjects_DTIROI_ROBUSTMEAN_20Feb2026.csv")
bsi = pd.read_csv("Tables/All_Subjects_FOXLABBSI_20Feb2026.csv")
bsi = bsi[bsi.PHASE.isin(["ADNI3","ADNI4"])]
fs = pd.read_csv("Tables/All_Subjects_UCSFFSX7_20Feb2026.csv",low_memory=False)
fs = fs[fs.PHASE.isin(["ADNI3","ADNI4"])]
table_to_study = fs

# %%
fs
# Out:
#        PHASE         PTID    RID VISCODE VISCODE2  IMAGEUID FIELD_STRENGTH  \
# 0      ADNI3   002_S_4213   4213    init      m72    888008             3T
# 6      ADNI3   041_S_5253   5253      y4     m102   1576293             3T
# 8      ADNI3   035_S_6480   6480      y1      m12   1194953             3T
# 12     ADNI4   941_S_6471   6471   4_m12      m72  10932490             3T
# 13     ADNI3   168_S_6086   6086      sc       sc    917090             3T
# ...      ...          ...    ...     ...      ...       ...            ...
# 12224  ADNI4   941_S_7074   7074   4_m24      m42  11455284             3T
# 12225  ADNI4   006_S_6243   6243   4_m24      m90  11494945             3T
# 12226  ADNI4  389_S_10070  10070   4_m12      m18  11488775             3T
# 12227  ADNI4  073_S_10006  10006   4_m24      m24  11468696             3T
# 12228  ADNI4   027_S_6961   6961   4_m12      m54  11466310             3T
#
#          EXAMDATE     RUNDATE    STATUS  ...        ST147SV        ST148SV  \
# 0      2017-08-14  2022-07-23   partial  ...  217434.885092  217173.802571
# 6      2022-04-05  2022-09-30   partial  ...  224326.718919  227507.621279
# 8      2019-07-31  2024-11-19   partial  ...  243787.275324  250039.192742
# 12     2024-08-27  2024-10-16  complete  ...  246390.072695  246485.281979
# 13     2017-10-13  2022-07-26   partial  ...  221605.243687  223505.738449
# ...           ...         ...       ...  ...            ...            ...
# 12224  2025-10-01  2025-10-31  complete  ...  219905.755164  219104.695787
# 12225  2025-11-19  2026-01-06  complete  ...  235507.672331  234696.915662
# 12226  2025-11-14  2026-01-06  complete  ...  265529.067888  260959.211646
# 12227  2025-10-13  2026-01-05  complete  ...  250778.033848  265470.115442
# 12228  2025-10-15  2026-01-06  complete  ...  194397.972978  196825.606017
#
#              ST149SV   ST150SV   ST151SV   ST152SV  ST153SV        ST154SV  \
# 0      434608.687663  175240.0  171111.0  346351.0  47936.0  576920.687663
# 6      451834.340198  277026.0  265788.0  542814.0  56219.0  627853.340198
# 8      493826.468066  218554.5  216599.5  435154.0  56660.0  669236.468066
# 12     492875.354675  239296.5  239755.5  479052.0  61836.0  671169.354675
# 13     445110.982136  211261.5  207829.5  419091.0  55916.0  602435.982136
# ...              ...       ...       ...       ...      ...            ...
# 12224  439010.450951  192598.0  191468.0  384066.0  50991.0  582962.450951
# 12225  470204.587993  241856.5  240102.5  481959.0  57991.0  650340.587993
# 12226  526488.279535  246891.0  239864.0  486755.0  63323.0  709839.279535
# 12227  516248.149290  236375.0  243449.0  479824.0  52932.0  675785.149290
# 12228  391223.578995  191103.5  189060.5  380164.0  50745.0  555121.578995
#
#          ST155SV         update_stamp
# 0       874725.0  2024-12-02 08:27:54
# 6      1088080.0  2024-12-02 08:27:54
# 8      1040202.0  2024-12-02 08:27:54
# 12     1052429.0  2024-12-02 08:27:54
# 13      969703.0  2024-12-02 08:27:54
# ...          ...                  ...
# 12224   910066.0  2026-01-16 12:03:30
# 12225  1050096.0  2026-01-16 12:03:30
# 12226  1117553.0  2026-01-16 12:03:30
# 12227  1068338.0  2026-01-16 12:03:30
# 12228   871011.0  2026-01-16 12:03:30
#
# [3411 rows x 347 columns]

# %%
from src import getyear
table_to_study = table_to_study.copy()
table_to_study["year"] = table_to_study.VISCODE.map(getyear)

# %%
merged = table_to_study.merge(diagnosis.drop("EXAMDATE",axis=1),on=["PTID","VISCODE"])
merged = merged[~merged.DIAGNOSIS.isna()]
merged.DIAGNOSIS = merged.DIAGNOSIS.apply(int)

# %%
merged.isna().sum().sort_values()[-50:]
# drop those columns with too many null values. Those columns most likely do not contain valuable information.
# Out:
# ST35CV                   361
# ST48TS                   361
# ST48TA                   361
# ST48SA                   361
# ST48CV                   361
# ST38TS                   361
# ST38TA                   361
# ST38SA                   361
# ST38CV                   361
# ST107SA                  361
# ST107CV                  361
# DXMDUE                  2158
# DXMDES                  2162
# DXMPTR1                 2164
# DXMPTR6                 2164
# DXMPTR4                 2164
# DXMPTR3                 2167
# DXMPTR5                 2168
# DXMPTR2                 2169
# DD_CRF_VERSION_LABEL    2256
# HAS_QC_ERROR            2256
# LANGUAGE_CODE           2256
# BGQC                    2258
# TEMPQC                  2258
# INSULAQC                2258
# OVERALLQC               2258
# FRONTQC                 2258
# OCCQC                   2258
# PARQC                   2258
# VENTQC                  2258
# HIPPOQC                 2258
# CWMQC                   2258
# DXDSEV                  3012
# DXDDUE                  3012
# DXAPP                   3060
# ST68SV                  3112
# DXMOTHET                3252
# ST8SV                   3358
# DXAPOSS                 3375
# DXODES                  3382
# DXCONFID                3399
# DXPDES                  3399
# DXPATYP                 3399
# DXOTHDEM                3399
# DXPCOG                  3399
# DXNODEP                 3399
# DXAD                    3399
# DXNORM                  3399
# DXAPROB                 3399
# DXMCI                   3399
# dtype: int64

# %%
merged = merged.dropna(axis=1,thresh=len(merged)-1000)
# merged = merged.drop(["RID_x","RID_y","IMAGEUID"],axis=1)
merged
# Out:
#      PHASE_x         PTID  RID_x VISCODE VISCODE2_x  IMAGEUID FIELD_STRENGTH  \
# 0      ADNI3   002_S_4213   4213    init        m72    888008             3T
# 1      ADNI3   041_S_5253   5253      y4       m102   1576293             3T
# 2      ADNI3   035_S_6480   6480      y1        m12   1194953             3T
# 3      ADNI4   941_S_6471   6471   4_m12        m72  10932490             3T
# 4      ADNI3   168_S_6086   6086      sc         sc    917090             3T
# ...      ...          ...    ...     ...        ...       ...            ...
# 3397   ADNI4   941_S_7074   7074   4_m24        m42  11455284             3T
# 3398   ADNI4   006_S_6243   6243   4_m24        m90  11494945             3T
# 3399   ADNI4  389_S_10070  10070   4_m12        m18  11488775             3T
# 3400   ADNI4  073_S_10006  10006   4_m24        m24  11468696             3T
# 3401   ADNI4   027_S_6961   6961   4_m12        m54  11466310             3T
#
#         EXAMDATE     RUNDATE    STATUS  ...  RID_y  VISCODE2_y  DIAGNOSIS  \
# 0     2017-08-14  2022-07-23   partial  ...   4213         m72          1
# 1     2022-04-05  2022-09-30   partial  ...   5253        m102          2
# 2     2019-07-31  2024-11-19   partial  ...   6480         m12          2
# 3     2024-08-27  2024-10-16  complete  ...   6471         m72          1
# 4     2017-10-13  2022-07-26   partial  ...   6086          sc          1
# ...          ...         ...       ...  ...    ...         ...        ...
# 3397  2025-10-01  2025-10-31  complete  ...   7074         m42          1
# 3398  2025-11-19  2026-01-06  complete  ...   6243         m90          1
# 3399  2025-11-14  2026-01-06  complete  ...  10070         m18          2
# 3400  2025-10-13  2026-01-05  complete  ...  10006         m24          1
# 3401  2025-10-15  2026-01-06  complete  ...   6961         m54          2
#
#       DXPARK  DXDEP      ID  SITEID   USERDATE   USERDATE2  \
# 0        0.0    0.0   10647       1 2017-08-18  2017-08-18
# 1        0.0    0.0  156076      28 2022-05-05  2022-05-05
# 2        0.0    0.0   92304      25 2019-08-07  2019-08-07
# 3        0.0    0.0   31696     941 2024-09-03  2024-09-03
# 4        0.0    0.0   17412      58 2017-10-20  2017-10-20
# ...      ...    ...     ...     ...        ...         ...
# 3397     0.0    0.0  120009     941 2025-09-11  2025-09-11
# 3398     0.0    0.0  133591       6 2026-01-13  2026-01-13
# 3399     0.0    0.0  132693     389 2025-12-23  2025-12-23
# 3400     0.0    0.0  124255      73 2025-10-09  2025-10-09
# 3401     0.0    1.0  124888      27 2025-10-16  2025-10-16
#
#            update_stamp_y
# 0     2017-08-17 22:44:55
# 1     2022-05-06 04:18:11
# 2     2019-08-08 04:15:41
# 3     2024-09-04 01:49:51
# 4     2017-10-20 22:28:07
# ...                   ...
# 3397  2025-09-12 01:53:05
# 3398  2026-01-14 00:56:57
# 3399  2025-12-24 00:58:05
# 3400  2025-10-10 01:51:58
# 3401  2025-10-17 01:53:10
#
# [3399 rows x 347 columns]

# %%
merged_num = merged.select_dtypes(include=['number'])
merged_num.year
# Out:
# 0       0
# 1       4
# 2       1
# 3       1
# 4      -1
#        ..
# 3397    2
# 3398    2
# 3399    1
# 3400    2
# 3401    1
# Name: year, Length: 3399, dtype: int64

# %%
merged_num.corrwith(merged_num.year).sort_values()[:20]
# Out:
# RID_x      -0.436507
# RID_y      -0.436507
# IMAGEUID   -0.298971
# ST51TA     -0.134058
# SITEID     -0.128224
# ST58TA     -0.126469
# ST110TA    -0.114275
# ST117TA    -0.110408
# ST15TA     -0.102121
# ST59TA     -0.101506
# ST18SV     -0.101132
# ST118TA    -0.099566
# ST61SV     -0.098212
# ST74TA     -0.097631
# ST31TA     -0.096205
# ST120SV    -0.094606
# ST12SV     -0.094585
# ST104TA    -0.094181
# ST90TA     -0.091932
# ST56TA     -0.091374
# dtype: float64

# %%
merged_num.corrwith(merged_num.DIAGNOSIS).sort_values()[-20:]
# Out:
# ST46TS       0.167563
# ST115TS      0.167883
# ST74TS       0.170246
# ST13TS       0.171485
# ST47TS       0.176170
# ST128SV      0.179870
# ST15TS       0.180472
# ST26TS       0.185527
# ST55TS       0.192400
# ST56TS       0.193962
# ST80SV       0.208186
# ST54TS       0.218356
# ST21SV       0.237157
# ST7SV        0.244265
# ST96SV       0.273717
# ST127SV      0.276297
# ST37SV       0.291046
# ST30SV       0.397657
# ST89SV       0.408526
# DIAGNOSIS    1.000000
# dtype: float64

# %%
import pandas as pd


# Run the function
anova_summary_diagnosis = run_batch_anova(merged_num, 'DIAGNOSIS')

# View the top 10 most significant features
print(anova_summary_diagnosis.head(50))
# Out:
#     Feature  F-Statistic        P-Value
# 0    ST29SV   390.793714  8.616958e-153
# 1    ST89SV   371.621136  1.499957e-146
# 2    ST24TA   364.975567  1.214998e-143
# 3    ST30SV   353.825031  3.421093e-140
# 4    ST83TA   333.706507  1.752859e-132
# 5    ST88SV   322.788393  1.406539e-128
# 6    ST12SV   292.366974  1.931667e-117
# 7    ST58TA   272.146773  8.934420e-110
# 8    ST40TA   264.700604  5.191482e-107
# 9    ST90TA   220.376535   2.183778e-90
# 10   ST31TA   219.694008   3.978881e-90
# 11  ST117TA   210.940415   1.023295e-86
# 12   ST71SV   210.072833   1.678326e-86
# 13   ST26TA   201.896640   4.373985e-83
# 14   ST59TA   196.425589   3.478623e-81
# 15   ST99TA   196.474264   3.759269e-81
# 16   ST70SV   194.088377   1.616673e-80
# 17   ST52TA   190.364663   4.577289e-79
# 18   ST85TA   181.185464   4.311855e-75
# 19   ST11SV   179.246785   1.030321e-74
# 20  ST111TA   177.555406   4.757434e-74
# 21  ST118TA   170.291934   5.288985e-71
# 22  ST130TA   167.967189   2.915190e-70
# 23   ST40CV   162.965179   4.385651e-68
# 24   ST37SV   159.930672   4.454430e-67
# 25   ST32TA   153.265131   2.961401e-64
# 26   ST91TA   148.720918   1.874458e-62
# 27   ST60TA   147.114851   8.140894e-62
# 28   ST99CV   144.979339   5.749621e-61
# 29   ST72TA   144.403646   6.650464e-61
# 30   ST24CV   143.561585   1.851849e-60
# 31   ST96SV   139.578442   5.825259e-59
# 32  ST127SV   139.200668   8.257113e-59
# 33  ST119TA   139.456864   9.119414e-59
# 34  ST153SV   137.850448   2.814926e-58
# 35   ST57TA   137.647938   4.521368e-58
# 36  ST116TA   137.384378   5.763222e-58
# 37   ST83CV   136.744754   9.782682e-58
# 38  ST147SV   135.314459   2.940737e-57
# 39   ST58CV   130.127776   4.932548e-55
# 40   ST26CV   129.242863   1.307219e-54
# 41   ST32CV   129.044555   1.342299e-54
# 42   ST44TA   128.208870   2.611185e-54
# 43  ST149SV   123.552617   1.633383e-52
# 44  ST129TA   121.704335   9.260096e-52
# 45   ST15TA   120.892861   2.247026e-51
# 46   ST90CV   119.784625   6.841194e-51
# 47   ST31CV   116.876608   1.025703e-49
# 48   ST13TA   115.641850   2.639805e-49
# 49  ST103TA   113.396307   2.527551e-48

# %%
anova_summary_year = run_batch_anova(merged_num, 'year')
print(anova_summary_year.head(50))
# Out:
#       Feature  F-Statistic       P-Value
# 0       RID_x   368.728469  0.000000e+00
# 1          ID   543.153213  0.000000e+00
# 2       RID_y   368.728469  0.000000e+00
# 3    IMAGEUID    76.131866  1.795518e-89
# 4   DIAGNOSIS    39.926200  3.467690e-47
# 5      ST98TS    31.733592  2.720792e-37
# 6     ST113TS    29.869605  4.473623e-35
# 7     ST127SV    28.362713  3.010015e-33
# 8      ST54TS    27.407963  4.288426e-32
# 9     ST129TS    25.970314  2.390665e-30
# 10     ST96SV    25.917628  2.775196e-30
# 11     ST39TS    25.653532  6.101549e-30
# 12    ST115TS    25.355824  1.400768e-29
# 13    ST114TS    25.106783  2.807704e-29
# 14     ST89SV    24.642590  9.804795e-29
# 15     ST91TS    24.598128  1.219566e-28
# 16     ST37SV    24.400808  1.928198e-28
# 17     ST32TS    24.340836  2.499896e-28
# 18     ST36TS    23.678164  1.448230e-27
# 19     ST56TS    23.117154  7.289850e-27
# 20     ST30SV    22.375111  5.590294e-26
# 21     ST95TS    21.823050  2.611000e-25
# 22     ST55TS    21.770394  3.151013e-25
# 23    ST130TS    21.251886  1.297424e-24
# 24     ST84TS    20.120690  3.185492e-23
# 25     ST25TS    20.030592  4.099064e-23
# 26     ST26TS    20.048698  4.160618e-23
# 27     ST40TS    20.005936  4.533737e-23
# 28     ST51TA    18.724785  1.584336e-21
# 29     ST99TS    18.016442  1.180068e-20
# 30    ST105TS    17.951294  1.342792e-20
# 31     ST21SV    17.921035  1.466217e-20
# 32     ST52TS    17.662647  3.014093e-20
# 33     ST46TS    17.640483  3.207148e-20
# 34     ST58TA    17.446702  5.801340e-20
# 35     ST74TS    16.955020  2.240870e-19
# 36     ST80SV    16.738530  4.020309e-19
# 37     ST73TS    15.369075  1.850325e-17
# 38    ST118TS    14.618883  1.549957e-16
# 39     ST15TS    14.373611  3.040923e-16
# 40     ST85TS    13.916145  1.123826e-15
# 41    ST117TA    13.895513  1.171448e-15
# 42     ST12SV    13.855438  1.295504e-15
# 43    ST110TA    13.668456  2.172994e-15
# 44    ST104TS    13.442339  4.019103e-15
# 45     ST47TS    13.320116  5.650931e-15
# 46    ST106TS    13.068357  1.139827e-14
# 47     ST59TA    13.071474  1.155886e-14
# 48    ST113TA    12.971450  1.493092e-14
# 49    ST128SV    12.822870  2.258428e-14

# %%
anova_summary_cross = run_batch_anova(merged_num[["year","DIAGNOSIS"]], 'DIAGNOSIS')
anova_summary_cross
# Out:
#   Feature  F-Statistic   P-Value
# 0    year     0.400264  0.670175

# %%
import seaborn as sns

# %%
plot_diagnosis_distribution(merged_num, 'ST29SV')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
plot_patient_progression(table_to_study, 'ST29SV')

# %%
my_patients = list(patients.PTID.unique())

# %%
import random
cn_patients = random.choices(list(cn.PTID.unique()),k=50)
mci_patients = random.choices(list(mci.PTID.unique()),k=50)
ad_patients = random.choices(list(ad.PTID.unique()),k=50)
all_patients = cn_patients+mci_patients+ad_patients

# %%
plot_specific_patients(merged, 'ST29SV', all_patients)

# %%
merged[merged.PTID.isin(mci_patients)]
# Out:
#      PHASE_x        PTID  RID_x VISCODE VISCODE2_x  IMAGEUID FIELD_STRENGTH  \
# 39     ADNI3  019_S_6757   6757      y4        m48  10260261             3T
# 47     ADNI3  130_S_6639   6639      sc         sc   1083233             3T
# 62     ADNI3  027_S_4919   4919    init        m48    814318             3T
# 97     ADNI3  005_S_6427   6427      sc         sc   1013508             3T
# 203    ADNI3  168_S_6817   6817      sc         sc   1236269             3T
# ...      ...         ...    ...     ...        ...       ...            ...
# 3167   ADNI4  052_S_4944   4944   4_m12       m150  11342273             3T
# 3201   ADNI4  067_S_4782   4782  4_init       m156  11433138             3T
# 3342   ADNI4  019_S_7016   7016   4_m12        m48  11482187             3T
# 3355   ADNI4  067_S_7020   7020   4_m12        m48  11475360             3T
# 3357   ADNI4  027_S_6788   6788   4_m12        m72  11455268             3T
#
#         EXAMDATE     RUNDATE    STATUS  ... RID_y  VISCODE2_y  DIAGNOSIS  \
# 39    2023-08-23  2024-08-08   partial  ...  6757         m48          2
# 47    2018-12-04  2022-09-29   partial  ...  6639          sc          2
# 62    2017-01-31  2022-09-28   partial  ...  4919         m48          2
# 97    2018-06-25  2022-07-23   partial  ...  6427          sc          2
# 203   2019-10-03  2022-07-26   partial  ...  6817          sc          2
# ...          ...         ...       ...  ...   ...         ...        ...
# 3167  2025-07-08  2025-08-11  complete  ...  4944        m150          2
# 3201  2025-09-04  2025-10-09  complete  ...  4782        m156          3
# 3342  2025-11-04  2026-01-05  complete  ...  7016         m48          2
# 3355  2025-10-28  2026-01-07  complete  ...  7020         m48          2
# 3357  2025-10-01  2025-10-31  complete  ...  6788         m72          3
#
#       DXPARK  DXDEP      ID  SITEID   USERDATE   USERDATE2  \
# 39       0.0    0.0  177879      14 2023-08-23  2023-12-21
# 47       0.0    0.0   76760      50 2019-02-26  2019-02-26
# 62       0.0    0.0      37      20 2016-12-07  2016-12-07
# 97       0.0    0.0   47814       3 2018-06-18  2018-06-18
# 203      0.0    0.0   99904      58 2019-10-16  2019-10-16
# ...      ...    ...     ...     ...        ...         ...
# 3167     1.0    0.0  121741      52 2025-09-25  2025-09-25
# 3201     0.0    0.0  119863      67 2025-09-10  2025-09-10
# 3342     0.0    0.0  127884      19 2025-11-07  2025-11-07
# 3355     0.0    0.0  126509      67 2025-10-29  2025-10-29
# 3357     0.0    0.0  123297      27 2025-10-02  2025-10-02
#
#            update_stamp_y
# 39    2023-12-22 04:24:59
# 47    2019-02-26 22:40:05
# 62    2017-08-14 22:27:43
# 97    2018-06-18 22:37:36
# 203   2019-10-17 04:18:18
# ...                   ...
# 3167  2025-09-26 01:52:39
# 3201  2025-09-11 01:51:39
# 3342  2025-11-08 00:56:42
# 3355  2025-10-30 01:52:54
# 3357  2025-10-03 01:54:13
#
# [99 rows x 347 columns]
