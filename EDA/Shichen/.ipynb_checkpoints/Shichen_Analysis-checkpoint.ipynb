# %%
import pandas as pd
from src import *
allimages = pd.read_csv("Tables/All_Subjects_All_Images_20Feb2026.csv")
diagnosis = pd.read_csv("Tables/All_Subjects_DXSUM_20Feb2026.csv")

# %%
# Load table of all images
allimages = pd.read_csv("Tables/All_Subjects_All_Images_20Feb2026.csv")

# %%
len(allimages[allimages.modality=="MRI"])
# Out:
# 230002

# %%
temp = allimages[allimages.image_type=='Pre-processed']
temp[(temp.phase=="ADNI 3")&temp.image_description.str.contains("T1 ")&(temp.modality=="MRI")]
# Out:
#         image_id  subject_id   phase  study_id modality     image_type  \
# 273807  11380943  127_S_1427  ADNI 3    115027      MRI  Pre-processed
# 273808  11380944  127_S_1427  ADNI 3    115027      MRI  Pre-processed
# 273809  11380949  127_S_1427  ADNI 3    115027      MRI  Pre-processed
# 273819  11386554  127_S_1427  ADNI 3    127633      MRI  Pre-processed
# 273820  11386556  127_S_1427  ADNI 3    127633      MRI  Pre-processed
# ...          ...         ...     ...       ...      ...            ...
# 335985  11365077  035_S_7115  ADNI 3    218809      MRI  Pre-processed
# 335986  11365082  035_S_7115  ADNI 3    218809      MRI  Pre-processed
# 336023  11365090  082_S_7117  ADNI 3    219059      MRI  Pre-processed
# 336024  11365095  082_S_7117  ADNI 3    219059      MRI  Pre-processed
# 336025  11365107  082_S_7117  ADNI 3    219059      MRI  Pre-processed
#
#        image_visit  image_date     image_description upload_date file_format  \
# 273807        init  2017-09-06   Reoriented T1 Image  2025-07-24       NIfTI
# 273808        init  2017-09-06         T1 Brain Mask  2025-07-24       NIfTI
# 273809        init  2017-09-06  T1 MUSE segmentation  2025-07-24       NIfTI
# 273819          y1  2018-10-12   Reoriented T1 Image  2025-07-28       NIfTI
# 273820          y1  2018-10-12         T1 Brain Mask  2025-07-28       NIfTI
# ...            ...         ...                   ...         ...         ...
# 335985          sc  2022-11-15         T1 Brain Mask  2025-07-23       NIfTI
# 335986          sc  2022-11-15  T1 MUSE segmentation  2025-07-23       NIfTI
# 336023          sc  2022-11-03   Reoriented T1 Image  2025-07-23       NIfTI
# 336024          sc  2022-11-03         T1 Brain Mask  2025-07-23       NIfTI
# 336025          sc  2022-11-03  T1 MUSE segmentation  2025-07-23       NIfTI
#
#        structure laterality
# 273807     Brain       Both
# 273808     Brain       Both
# 273809     Brain       Both
# 273819     Brain       Both
# 273820     Brain       Both
# ...          ...        ...
# 335985     Brain       Both
# 335986     Brain       Both
# 336023     Brain       Both
# 336024     Brain       Both
# 336025     Brain       Both
#
# [6720 rows x 13 columns]

# %%
mris = allimages[
    (allimages.modality=="MRI")&
    (allimages.image_type=="Original")
    ]

# %%
mris.image_description.value_counts()[:50]
# Out:
# image_description
# 3 Plane Localizer                      12014
# localizer                               7604
# Axial 3D ME T2 GRE (MSV21)              7183
# 3-plane localizer                       5823
# MPRAGE                                  5558
# Field Mapping                           5522
# Axial PD-T2 TSE                         3942
# Axial PD/T2 FSE                         3822
# Localizer                               3288
# Axial T2-FLAIR                          3041
# Axial T2 Star                           2370
# Sagittal 3D FLAIR                       2324
# Axial 3TE T2 STAR                       2256
# AXIAL_T2_STAR                           2075
# MPRAGE GRAPPA2                          2061
# MP-RAGE                                 2037
# MPRAGE Repeat                           1961
# B1-calibration Body                     1897
# B1-calibration Head                     1866
# MP-RAGE REPEAT                          1669
# HighResHippo                            1487
# B1-Calibration Body                     1479
# B1-Calibration PA                       1461
# Accelerated Sagittal MPRAGE             1445
# HighResHippocampus                      1417
# Calibration Scan                        1338
# Field_mapping                           1221
# Axial FLAIR                             1101
# Sagittal 3D FLAIR (MSV22)                999
# Accelerated Sagittal MPRAGE (MSV21)      948
# Axial T2 TSE with Fat Sat                939
# SURVEY                                   898
# Axial T2-Star                            871
# Head,3-P,2D,LOCALIZER                    870
# HighResHippocampus (MSV21)               858
# MPRAGE SENSE2                            856
# Sagittal 3D T2 SPACE (MSV21)             793
# Double_TSE                               711
# Sag IR-SPGR                              689
# Accelerated Sag IR-FSPGR                 683
# LOC                                      669
# ADNI_gre_field_mapping                   667
# FSE PD/T2                                602
# Axial Field Mapping                      570
# Circle Scout                             550
# Axial T2 STAR                            543
# Sag IR-FSPGR                             430
# 3-pl T2* FGRE                            414
# Accelerated SAG IR-SPGR                  414
# Isotropic image                          410
# Name: count, dtype: int64

# %%
mris.subject_id.value_counts()[-10:]
# Out:
# subject_id
# 404_S_10895    4
# 404_S_10853    4
# 404_S_10898    4
# 005_S_10446    3
# 381_S_10578    3
# 941_S_10010    3
# 100_S_10035    3
# 073_S_10228    3
# 005_S_10240    3
# 022_S_10055    2
# Name: count, dtype: int64

# %%
mris34 = mris[(mris.phase=="ADNI 3")|(mris.phase=="ADNI 4")]
len(mris34)
# Out:
# 37622

# %%
mris3 = mris[(mris.phase=="ADNI 3")]
len(mris3)
# Out:
# 25313

# %%
mris3.image_description.value_counts()[:50]
# Out:
# image_description
# 3 Plane Localizer                                                  6648
# Field Mapping                                                      4032
# Sagittal 3D FLAIR                                                  2314
# Axial 3TE T2 STAR                                                  2256
# Accelerated Sagittal MPRAGE                                        1438
# HighResHippocampus                                                 1410
# Axial T2 Star                                                      1320
# Axial Field Mapping                                                 570
# Axial T2 STAR                                                       543
# HighResHippo                                                        536
# Calibration Scan                                                    375
# Sagittal 3D Accelerated MPRAGE                                      353
# HighResHippo Scan (Oblique - perpendicular to hippocampal tail      343
# Accelerated Sag IR-FSPGR                                            310
# Accelerated Sagittal IR-FSPGR                                       258
# Accelerated Sagittal MPRAGE_ND                                      258
# Axial 3TE T2 Star                                                   237
# 3TE Axial T2 Star                                                   186
# Field Mapping phase R-L                                             174
# Isotropic image                                                     148
# AAHead_Scout_MPR_sag                                                136
# AAHead_Scout                                                        121
# HighResHippo Scan (Oblique - perpendicular to hippocampal tail)      79
# Axial 3TE T2 STAR  straight no angle                                 72
# COR HighResHippo                                                     66
# Accelerated Sagittal MPRAGE Phase A-P                                59
# Sagittal 3D FLAIR phase A-P                                          59
# Axial T2 STAR phase R-L                                              58
# HighResHippocampus Phase R-L                                         58
# Axial Field Mapping 0 angle                                          58
# Cal 8HRBRAIN                                                         54
# SCOUT                                                                48
# Field_Mapping                                                        39
# Field Mapping_ND                                                     39
# Field Mapping    straight no angle                                   36
# Axial T2 Star (NO ANGLE)                                             33
# Axial T2 0 angle Star                                                32
# Sagittal 3D Accelerated 0 angle MPRAGE                               29
# Sagittal 3D 0 angle FLAIR                                            29
# Localizer                                                            25
# SWI_Images                                                           24
# mIP_Images(SW)                                                       24
# Obl HighResHippo                                                     20
# Axial 3D ME T2 GRE (MSV21)                                           20
# Sag Accel IR-FSPGR                                                   19
# localizer                                                            18
# Axial Field Mapping straight                                         16
# Field Mapping Phase Direction P>A                                    15
# Cal RM:8HRBRAIN                                                      10
# 3_Plane_Localizer                                                     9
# Name: count, dtype: int64

# %%
mris34.subject_id.nunique()
# Out:
# 1796

# %%
mris34.subject_id.value_counts()[1000:1010]
# Out:
# subject_id
# 003_S_10158    14
# 073_S_10167    14
# 073_S_10172    14
# 941_S_10148    14
# 389_S_10140    14
# 022_S_10136    14
# 014_S_10180    14
# 073_S_10089    14
# 052_S_10242    14
# 016_S_10190    14
# Name: count, dtype: int64

# %%
# Load table of diagnosis
diagnosis = pd.read_csv("Tables/All_Subjects_DXSUM_20Feb2026.csv")
diagnosis.USERDATE = diagnosis.USERDATE.apply(pd.to_datetime)
diagnosis34 = diagnosis[
    (diagnosis.PHASE=="ADNI3")
    ]

# %%
diagnosis_ = {}
for i in [1,"GO",2,3,4]:
    diagnosis_[i] = diagnosis[diagnosis.PHASE==f"ADNI{i}"]

# %%
for i in [1,"GO",2,3,4]:
    print(f"Count of patients in phase {i}: {diagnosis_[i].PTID.nunique()}")

p = [1,"GO",2,3,4]
for i in range(4):
    print(f"Count of patients in phase {p[i]} that didn't continue in phase {p[i+1]}: {diagnosis_[p[i]][~diagnosis_[p[i]].PTID.isin(diagnosis_[p[i+1]].PTID)].PTID.nunique()}")
# Out:
# Count of patients in phase 1: 819
# Count of patients in phase GO: 338
# Count of patients in phase 2: 1438
# Count of patients in phase 3: 1376
# Count of patients in phase 4: 1339
# Count of patients in phase 1 that didn't continue in phase GO: 610
# Count of patients in phase GO that didn't continue in phase 2: 41
# Count of patients in phase 2 that didn't continue in phase 3: 1028
# Count of patients in phase 3 that didn't continue in phase 4: 860

# %%
diagnosis.PTID.nunique()
# Out:
# 3789

# %%
diagnosis[diagnosis.PTID=="007_S_6341"]
# Out:
#        PHASE        PTID   RID VISCODE VISCODE2    EXAMDATE  DIAGNOSIS  \
# 10729  ADNI3  007_S_6341  6341      sc       sc  2018-04-30        2.0
# 10839  ADNI3  007_S_6341  6341      bl       bl  2018-06-07        2.0
# 11651  ADNI3  007_S_6341  6341      y1      m12  2019-06-11        2.0
# 12300  ADNI3  007_S_6341  6341      y2      m24  2020-08-19        2.0
# 12692  ADNI3  007_S_6341  6341      y3      m36  2021-07-19        3.0
# 13121  ADNI3  007_S_6341  6341      y4      m48  2022-05-24        3.0
# 13440  ADNI3  007_S_6341  6341      y5      m60  2023-05-16        3.0
# 13877  ADNI4  007_S_6341  6341  4_init      m72  2024-05-21        3.0
#
#        DXNORM  DXNODEP  DXMCI  ... DXODES  DXCONFID      ID  SITEID  \
# 10729     NaN      NaN    NaN  ...    NaN       NaN   41028       5
# 10839     NaN      NaN    NaN  ...    NaN       NaN   46293       5
# 11651     NaN      NaN    NaN  ...    NaN       NaN   86339       5
# 12300     NaN      NaN    NaN  ...    NaN       NaN  117889       5
# 12692     NaN      NaN    NaN  ...    NaN       NaN  138263       5
# 13121     NaN      NaN    NaN  ...    NaN       NaN  157619       5
# 13440     NaN      NaN    NaN  ...    NaN       NaN  175120       5
# 13877     NaN      NaN    NaN  ...    NaN       NaN   17265       7
#
#         USERDATE   USERDATE2  DD_CRF_VERSION_LABEL  LANGUAGE_CODE  \
# 10729 2018-05-04  2018-05-04                   NaN            NaN
# 10839 2018-06-08  2018-06-08                   NaN            NaN
# 11651 2019-06-18  2019-06-18                   NaN            NaN
# 12300 2020-08-24  2020-08-26                   NaN            NaN
# 12692 2021-07-21  2021-07-21                   NaN            NaN
# 13121 2022-05-31  2022-05-31                   NaN            NaN
# 13440 2023-05-17  2023-05-17                   NaN            NaN
# 13877 2024-05-28  2024-05-28                    v1              e
#
#       HAS_QC_ERROR         update_stamp
# 10729          NaN  2018-05-04 22:38:16
# 10839          NaN  2018-06-08 22:37:32
# 11651          NaN  2019-06-18 09:50:36
# 12300          NaN  2020-08-27 04:16:42
# 12692          NaN  2021-07-22 04:17:49
# 13121          NaN  2022-06-01 04:18:49
# 13440          NaN  2023-05-18 04:20:28
# 13877          0.0  2024-05-29 01:39:34
#
# [8 rows x 41 columns]

# %%
allimages3 = allimages[(allimages.phase=="ADNI 3")&(allimages.modality=="MRI")]

# %%
cn = diagnosis34[diagnosis34.DIAGNOSIS==1.0][["PTID","USERDATE","DIAGNOSIS"]]
mci = diagnosis34[diagnosis34.DIAGNOSIS==2.0][["PTID","USERDATE","DIAGNOSIS"]]
ad = diagnosis34[diagnosis34.DIAGNOSIS==3.0][["PTID","USERDATE","DIAGNOSIS"]]

# %%
#### Transition patients
patients = pd.merge(mci,ad,on="PTID")
times = patients.groupby("PTID")["USERDATE_y"].max()-patients.groupby("PTID")["USERDATE_x"].min()
cleaned_times = times[times>pd.Timedelta(0)]
times

### always same diagnosis patients:
# patients = mci[(~mci.PTID.isin(cn.PTID))&(~mci.PTID.isin(ad.PTID))]
# times = patients.groupby("PTID")["USERDATE"].max()-patients.groupby("PTID")["USERDATE"].min()
# cleaned_times = times
# times
# Out:
# PTID
# 003_S_4354   1287 days
# 006_S_6252    552 days
# 006_S_6770   1350 days
# 007_S_4272   1817 days
# 007_S_4637    324 days
# 007_S_5265    385 days
# 007_S_6341   1839 days
# 012_S_6073   1808 days
# 014_S_2185    715 days
# 016_S_6800    607 days
# 016_S_6939    376 days
# 018_S_2155   1918 days
# 019_S_6483   1859 days
# 019_S_6668   1863 days
# 021_S_5237   1509 days
# 022_S_6863    601 days
# 023_S_4115   1475 days
# 023_S_6535   1175 days
# 027_S_6034   1739 days
# 027_S_6640    874 days
# 027_S_6788    852 days
# 033_S_6497   1150 days
# 033_S_7088    399 days
# 035_S_4114    733 days
# 035_S_7000    789 days
# 036_S_2380    900 days
# 036_S_4538   1049 days
# 037_S_0467    781 days
# 037_S_6222    937 days
# 041_S_4271    547 days
# 041_S_6731   1548 days
# 067_S_4782   1495 days
# 067_S_6529   1136 days
# 070_S_6911    433 days
# 098_S_0896    390 days
# 099_S_6632   1191 days
# 114_S_5047   2073 days
# 126_S_0605   1810 days
# 126_S_4891   1824 days
# 126_S_6724   1176 days
# 127_S_6241   1841 days
# 128_S_2130   1102 days
# 128_S_2220   1370 days
# 129_S_4422    762 days
# 129_S_6852    773 days
# 131_S_6805   1226 days
# 135_S_6411   1040 days
# 137_S_4862    878 days
# 153_S_6755   1876 days
# 168_S_6467    838 days
# 168_S_6634   1661 days
# 168_S_6908    859 days
# 305_S_6810   -552 days
# 941_S_4365   1814 days
# 941_S_6068   1825 days
# 941_S_6345    896 days
# dtype: timedelta64[us]

# %%
diagnosis34[diagnosis34.PTID.isin(allimages3.subject_id)].PTID.nunique()
# Out:
# 1150

# %%
len(cleaned_times)
# Out:
# 55

# %%
visits = allimages3[allimages3.subject_id.isin(cleaned_times.index)]

# %%
visits.groupby("subject_id")["image_date"].unique().apply(len).mean()
# Out:
# np.float64(3.2264150943396226)

# %%
visits.groupby("subject_id")["image_date"].unique()
# Out:
# subject_id
# 003_S_4354     [2017-06-13, 2018-12-19, 2019-06-25, 2021-06-23]
# 006_S_6252                             [2018-03-05, 2019-05-06]
# 006_S_6770                 [2019-07-26, 2022-09-01, 2021-09-01]
# 007_S_4272    [2018-01-16, 2019-01-08, 2020-01-31, 2021-02-2...
# 007_S_4637     [2017-10-10, 2018-10-16, 2019-10-23, 2022-10-20]
# 007_S_5265    [2017-09-18, 2018-09-25, 2019-09-17, 2021-09-2...
# 007_S_6341     [2018-04-30, 2019-06-11, 2020-08-18, 2021-06-28]
# 012_S_6073     [2017-09-22, 2018-10-31, 2019-10-07, 2021-01-13]
# 016_S_6800                             [2019-08-19, 2021-03-08]
# 016_S_6939                             [2021-05-06, 2022-07-08]
# 018_S_2155    [2017-09-20, 2018-08-28, 2019-09-17, 2020-10-2...
# 019_S_6483    [2018-07-11, 2019-08-05, 2020-08-04, 2021-08-0...
# 019_S_6668                 [2019-01-23, 2021-02-16, 2024-02-14]
# 021_S_5237                 [2018-08-15, 2019-07-30, 2020-09-15]
# 022_S_6863                             [2020-08-20, 2021-10-27]
# 023_S_4115    [2018-01-24, 2019-01-15, 2020-01-13, 2021-04-2...
# 023_S_6535     [2018-08-02, 2019-09-18, 2022-09-15, 2021-09-14]
# 027_S_6034                 [2017-07-06, 2019-07-24, 2021-07-20]
# 027_S_6640                             [2018-12-26, 2021-05-12]
# 027_S_6788                 [2019-08-05, 2020-11-12, 2021-12-03]
# 033_S_6497                             [2019-06-11, 2018-07-16]
# 033_S_7088                             [2022-06-27, 2023-07-21]
# 035_S_4114                 [2017-09-22, 2018-09-26, 2019-10-08]
# 035_S_7000                 [2021-09-07, 2022-09-27, 2023-10-04]
# 036_S_2380                 [2018-06-18, 2019-06-05, 2021-01-12]
# 036_S_4538                 [2017-10-31, 2018-12-19, 2020-09-14]
# 037_S_6222     [2018-05-30, 2019-09-05, 2020-11-10, 2021-08-18]
# 041_S_4271                 [2017-09-29, 2018-11-09, 2019-09-17]
# 041_S_6731     [2019-05-28, 2020-10-16, 2023-07-31, 2022-06-27]
# 067_S_4782     [2017-08-29, 2018-08-20, 2019-10-02, 2021-10-05]
# 067_S_6529                 [2018-08-14, 2020-01-17, 2021-08-18]
# 070_S_6911                             [2021-03-03, 2022-05-09]
# 098_S_0896                             [2018-03-15, 2019-05-09]
# 099_S_6632     [2018-12-19, 2020-02-07, 2021-01-20, 2022-03-03]
# 114_S_5047                                         [2018-07-24]
# 126_S_0605                                         [2018-07-10]
# 126_S_4891    [2018-07-27, 2019-08-14, 2020-09-23, 2021-07-1...
# 126_S_6724     [2019-05-02, 2020-10-07, 2021-06-17, 2022-06-20]
# 127_S_6241    [2020-08-25, 2018-05-29, 2019-08-06, 2021-06-1...
# 128_S_2130                             [2018-09-14, 2021-10-07]
# 128_S_2220                 [2018-07-16, 2019-07-12, 2022-06-23]
# 129_S_4422                             [2017-03-21, 2018-03-15]
# 129_S_6852                 [2020-02-05, 2021-02-10, 2022-02-21]
# 131_S_6805                 [2019-09-12, 2021-11-17, 2020-11-23]
# 135_S_6411    [2018-06-04, 2020-08-26, 2021-06-09, 2022-06-1...
# 137_S_4862                 [2018-10-05, 2019-09-10, 2020-10-16]
# 153_S_6755                                         [2019-06-19]
# 168_S_6467                             [2018-07-05, 2019-10-02]
# 168_S_6634     [2018-11-27, 2020-02-26, 2021-02-16, 2023-07-05]
# 168_S_6908                                         [2021-03-01]
# 941_S_4365                 [2017-08-28, 2018-08-28, 2021-08-31]
# 941_S_6068     [2017-08-21, 2018-08-17, 2019-09-10, 2021-08-17]
# 941_S_6345                 [2018-05-10, 2019-05-29, 2020-09-08]
# Name: image_date, dtype: object

# %%
times.mean()
# Out:
# Timedelta('1133 days 20:08:34.285714')

# %%
diagnosis[diagnosis.PTID=="941_S_4100"]
# Out:
#        PHASE        PTID   RID VISCODE VISCODE2    EXAMDATE  DIAGNOSIS  \
# 4486   ADNI2  941_S_4100  4100     v01       sc  2011-06-27        1.0
# 4603   ADNI2  941_S_4100  4100     v03       bl  2011-08-16        1.0
# 5876   ADNI2  941_S_4100  4100     v05      m06  2012-06-01        1.0
# 6473   ADNI2  941_S_4100  4100     v11      m12  2012-08-31        1.0
# 8780   ADNI2  941_S_4100  4100     v21      m24  2014-07-03        1.0
# 9380   ADNI2  941_S_4100  4100     v41      m48  2015-08-28        2.0
# 10296  ADNI3  941_S_4100  4100    init      m72  2017-10-26        2.0
# 11397  ADNI3  941_S_4100  4100      y1      m90  2018-11-19        2.0
# 13283  ADNI3  941_S_4100  4100      y4      NaN         NaN        1.0
#
#        DXNORM  DXNODEP  DXMCI  ... DXODES  DXCONFID      ID  SITEID  \
# 4486      NaN      NaN    NaN  ...    NaN       NaN     302      58
# 4603      NaN      NaN    NaN  ...    NaN       NaN     536      58
# 5876      NaN      NaN    NaN  ...    NaN       NaN    3084      58
# 6473      NaN      NaN    NaN  ...    NaN       NaN    4278      58
# 8780      NaN      NaN    NaN  ...    NaN       NaN    8896      58
# 9380      NaN      NaN    NaN  ...    NaN       NaN   10100      58
# 10296     NaN      NaN    NaN  ...    NaN       NaN   18832      59
# 11397     NaN      NaN    NaN  ...    NaN       NaN   73585      59
# 13283     NaN      NaN    NaN  ...    NaN       NaN  165018      59
#
#         USERDATE   USERDATE2  DD_CRF_VERSION_LABEL  LANGUAGE_CODE  \
# 4486  2011-07-05         NaN                   NaN            NaN
# 4603  2011-08-22         NaN                   NaN            NaN
# 5876  2012-06-04         NaN                   NaN            NaN
# 6473  2012-10-05         NaN                   NaN            NaN
# 8780  2014-07-03         NaN                   NaN            NaN
# 9380  2015-09-01         NaN                   NaN            NaN
# 10296 2017-11-01  2017-11-01                   NaN            NaN
# 11397 2019-01-16  2019-01-16                   NaN            NaN
# 13283 2022-09-07  2022-09-07                   NaN            NaN
#
#       HAS_QC_ERROR         update_stamp
# 4486           NaN  2013-03-14 19:16:45
# 4603           NaN  2013-03-14 19:16:45
# 5876           NaN  2013-03-14 19:16:46
# 6473           NaN  2013-03-14 19:16:46
# 8780           NaN  2014-07-03 19:16:58
# 9380           NaN  2015-09-01 19:17:01
# 10296          NaN  2017-11-01 22:28:13
# 11397          NaN  2021-07-29 04:17:59
# 13283          NaN  2022-09-08 04:19:08
#
# [9 rows x 41 columns]

# %%
diagnosis34.PTID.nunique()
# Out:
# 1376

# %%
mrist1w = mris[
    mris.image_description.str.contains("RAGE")|
    mris.image_description.str.contains("SPGR")
    ]
len(mrist1w)
# Out:
# 23875

# %%
mrist1w.image_description.value_counts()[:20]
# Out:
# image_description
# MPRAGE                                 5558
# MPRAGE GRAPPA2                         2061
# MP-RAGE                                2037
# MPRAGE Repeat                          1961
# MP-RAGE REPEAT                         1669
# Accelerated Sagittal MPRAGE            1445
# Accelerated Sagittal MPRAGE (MSV21)     948
# MPRAGE SENSE2                           856
# Sag IR-SPGR                             689
# Accelerated Sag IR-FSPGR                683
# Sag IR-FSPGR                            430
# Accelerated SAG IR-SPGR                 414
# Sagittal 3D Accelerated MPRAGE          355
# MPRAGE_GRAPPA2                          334
# Accelerated Sag IR-SPGR                 280
# MP-RAGE-Repeat                          268
# Accelerated Sagittal IR-FSPGR           258
# Accelerated Sagittal MPRAGE_ND          258
# IR-FSPGR-Repeat                         164
# IR-FSPGR                                154
# Name: count, dtype: int64

# %%
len(allimages)
# Out:
# 349508

# %%
mris34t1w = mris34[
    mris34.image_description.str.contains("RAGE")|
    mris34.image_description.str.contains("SPGR")
    ]
len(mris34t1w)
# Out:
# 4199

# %%
mris34t1w
# Out:
#         image_id   subject_id   phase  study_id modality image_type  \
# 439       901027   127_S_1427  ADNI 3    115027      MRI   Original
# 468      1059960   127_S_1427  ADNI 3    127633      MRI   Original
# 481      1234305   127_S_1427  ADNI 3    143233      MRI   Original
# 1888      955206   007_S_1222  ADNI 3    119402      MRI   Original
# 1904     1291745   007_S_1222  ADNI 3    149786      MRI   Original
# ...          ...          ...     ...       ...      ...        ...
# 349450  11427809  158_S_10782  ADNI 4    371686      MRI   Original
# 349467  11433172  158_S_10843  ADNI 4    371690      MRI   Original
# 349468  11433173  158_S_10843  ADNI 4    371690      MRI   Original
# 349485  11448624  158_S_10850  ADNI 4    373514      MRI   Original
# 349486  11448625  158_S_10850  ADNI 4    373514      MRI   Original
#
#        image_visit  image_date                    image_description  \
# 439           init  2017-09-06        Accelerated Sagittal IR-FSPGR
# 468             y1  2018-10-12        Accelerated Sagittal IR-FSPGR
# 481             y2  2019-09-30        Accelerated Sagittal IR-FSPGR
# 1888          init  2018-01-17          Accelerated Sagittal MPRAGE
# 1904            y2  2020-02-18          Accelerated Sagittal MPRAGE
# ...            ...         ...                                  ...
# 349450        4_sc  2025-07-22           CS Sagittal MPRAGE (MSV22)
# 349467        4_sc  2025-07-18  Accelerated Sagittal MPRAGE (MSV21)
# 349468        4_sc  2025-07-18           CS Sagittal MPRAGE (MSV22)
# 349485        4_sc  2025-07-18  Accelerated Sagittal MPRAGE (MSV21)
# 349486        4_sc  2025-07-18           CS Sagittal MPRAGE (MSV22)
#
#        upload_date file_format structure laterality
# 439     2017-09-06       DICOM     Brain       Both
# 468     2018-10-15       DICOM     Brain       Both
# 481     2019-09-30       DICOM     Brain       Both
# 1888    2018-01-18       DICOM     Brain       Both
# 1904    2020-02-18       DICOM     Brain       Both
# ...            ...         ...       ...        ...
# 349450  2025-08-29       DICOM     Brain       Both
# 349467  2025-09-08       DICOM     Brain       Both
# 349468  2025-09-08       DICOM     Brain       Both
# 349485  2025-09-25       DICOM     Brain       Both
# 349486  2025-09-25       DICOM     Brain       Both
#
# [4199 rows x 13 columns]

# %%
mris34t1w.subject_id.nunique()
# Out:
# 1796

# %%
mris34t1w.image_date = mris34t1w.image_date.apply(pd.to_datetime)
span_counts34 = mris34t1w.groupby("subject_id")["image_date"].agg(lambda x:x.max()-x.min())

# %%
len(span_counts34[span_counts34>pd.Timedelta("1056 days")])
# Out:
# 504

# %%
mrist1w.image_date = mrist1w.image_date.apply(pd.to_datetime)
span_counts = mrist1w.groupby("subject_id")["image_date"].agg(lambda x:x.max()-x.min())

# %%
len(span_counts[span_counts>pd.Timedelta("365 days")])
# Out:
# 2056

# %%
biomark = pd.read_csv("Tables/All_Subjects_BIOMARK_20Feb2026.csv",low_memory=False)

# %%
biomark.update_stamp = biomark.update_stamp.apply(pd.to_datetime)
biomark_span = biomark.groupby("PTID")["update_stamp"].agg(lambda x:x.max()-x.min())

# %%
len(biomark_span[biomark_span>pd.Timedelta("360 days")])
# Out:
# 1929

# %%
biomark34 = biomark[
    (biomark.PHASE=="ADNI3")|
    (biomark.PHASE=="ADNI4")
    ]

# %%
biomark34.update_stamp = biomark34.update_stamp.apply(pd.to_datetime)
biomark34_span = biomark34.groupby("PTID")["update_stamp"].agg(lambda x:x.max()-x.min())

# %%
len(biomark34_span[biomark34_span>pd.Timedelta("365 days")])
# Out:
# 803

# %%
merged = pd.merge(biomark34_span,span_counts34,left_on="PTID",right_on="subject_id")

# %%
len(merged)
# Out:
# 1581

# %%
t = pd.Timedelta("1095 days")
len(merged[(merged.update_stamp>t)&(merged.image_date>t)])
# Out:
# 443

# %%
mris34t1w.image_visit.value_counts()
# Out:
# image_visit
# sc        925
# 4_sc      777
# y2        569
# y1        474
# 4_init    409
# init      388
# y4        269
# 4_m12     198
# y3        116
# y5         37
# 4_m24      37
# Name: count, dtype: int64

# %%
mris34t1w[mris34t1w.image_visit=="sc"]
# Out:
#         image_id  subject_id   phase  study_id modality image_type  \
# 237514   1092019  341_S_6653  ADNI 3    130447      MRI   Original
# 237555   1118713  002_S_6652  ADNI 3    132824      MRI   Original
# 237614   1100512  027_S_6640  ADNI 3    131250      MRI   Original
# 237677   1119493  098_S_6655  ADNI 3    132900      MRI   Original
# 237708   1100527  027_S_6643  ADNI 3    131251      MRI   Original
# ...          ...         ...     ...       ...      ...        ...
# 273700   1668914  035_S_7120  ADNI 3    223783      MRI   Original
# 273718   1669252  035_S_7121  ADNI 3    223831      MRI   Original
# 273733   1679245  035_S_7123  ADNI 3    227360      MRI   Original
# 328948  10227031  153_S_6679  ADNI 3    236941      MRI   Original
# 336659  10239114  123_S_7125  ADNI 3    240466      MRI   Original
#
#        image_visit image_date                      image_description  \
# 237514          sc 2018-12-19            Accelerated Sagittal MPRAGE
# 237555          sc 2018-12-13            Accelerated Sagittal MPRAGE
# 237614          sc 2018-12-26          Accelerated Sagittal IR-FSPGR
# 237677          sc 2019-01-07                     Sag Accel IR-FSPGR
# 237708          sc 2018-12-26          Accelerated Sagittal IR-FSPGR
# ...            ...        ...                                    ...
# 273700          sc 2023-02-08  Accelerated Sagittal MPRAGE Phase A-P
# 273718          sc 2023-02-15  Accelerated Sagittal MPRAGE Phase A-P
# 273733          sc 2023-03-14  Accelerated Sagittal MPRAGE Phase A-P
# 328948          sc 2019-01-28            Accelerated Sagittal MPRAGE
# 336659          sc 2023-06-27         Sagittal 3D Accelerated MPRAGE
#
#        upload_date file_format structure laterality
# 237514  2018-12-19       DICOM     Brain       Both
# 237555  2019-01-22       DICOM     Brain       Both
# 237614  2018-12-27       DICOM     Brain       Both
# 237677  2019-01-23       DICOM     Brain       Both
# 237708  2018-12-27       DICOM     Brain       Both
# ...            ...         ...       ...        ...
# 273700  2023-02-22       DICOM     Brain       Both
# 273718  2023-02-22       DICOM     Brain       Both
# 273733  2023-03-17       DICOM     Brain       Both
# 328948  2023-05-22       DICOM     Brain       Both
# 336659  2023-06-28       DICOM     Brain       Both
#
# [925 rows x 13 columns]

# %%
dti = pd.read_csv("Tables/All_Subjects_DTIROI_MEAN_20Feb2026.csv")
robust = pd.read_csv("Tables/All_Subjects_DTIROI_ROBUSTMEAN_20Feb2026.csv")
bsi = pd.read_csv("Tables/All_Subjects_FOXLABBSI_20Feb2026.csv")
bsi = bsi[bsi.PHASE.isin(["ADNI3","ADNI4"])]
fs = pd.read_csv("Tables/All_Subjects_UCSFFSX7_20Feb2026.csv",low_memory=False)
fs = fs[fs.PHASE.isin(["ADNI3","ADNI4"])]
table = fs

# %%
fs
# Out:
#        PHASE         PTID    RID VISCODE VISCODE2  IMAGEUID FIELD_STRENGTH  \
# 0      ADNI3   002_S_4213   4213    init      m72    888008             3T
# 6      ADNI3   041_S_5253   5253      y4     m102   1576293             3T
# 8      ADNI3   035_S_6480   6480      y1      m12   1194953             3T
# 12     ADNI4   941_S_6471   6471   4_m12      m72  10932490             3T
# 13     ADNI3   168_S_6086   6086      sc       sc    917090             3T
# ...      ...          ...    ...     ...      ...       ...            ...
# 12224  ADNI4   941_S_7074   7074   4_m24      m42  11455284             3T
# 12225  ADNI4   006_S_6243   6243   4_m24      m90  11494945             3T
# 12226  ADNI4  389_S_10070  10070   4_m12      m18  11488775             3T
# 12227  ADNI4  073_S_10006  10006   4_m24      m24  11468696             3T
# 12228  ADNI4   027_S_6961   6961   4_m12      m54  11466310             3T
#
#          EXAMDATE     RUNDATE    STATUS  ...        ST147SV        ST148SV  \
# 0      2017-08-14  2022-07-23   partial  ...  217434.885092  217173.802571
# 6      2022-04-05  2022-09-30   partial  ...  224326.718919  227507.621279
# 8      2019-07-31  2024-11-19   partial  ...  243787.275324  250039.192742
# 12     2024-08-27  2024-10-16  complete  ...  246390.072695  246485.281979
# 13     2017-10-13  2022-07-26   partial  ...  221605.243687  223505.738449
# ...           ...         ...       ...  ...            ...            ...
# 12224  2025-10-01  2025-10-31  complete  ...  219905.755164  219104.695787
# 12225  2025-11-19  2026-01-06  complete  ...  235507.672331  234696.915662
# 12226  2025-11-14  2026-01-06  complete  ...  265529.067888  260959.211646
# 12227  2025-10-13  2026-01-05  complete  ...  250778.033848  265470.115442
# 12228  2025-10-15  2026-01-06  complete  ...  194397.972978  196825.606017
#
#              ST149SV   ST150SV   ST151SV   ST152SV  ST153SV        ST154SV  \
# 0      434608.687663  175240.0  171111.0  346351.0  47936.0  576920.687663
# 6      451834.340198  277026.0  265788.0  542814.0  56219.0  627853.340198
# 8      493826.468066  218554.5  216599.5  435154.0  56660.0  669236.468066
# 12     492875.354675  239296.5  239755.5  479052.0  61836.0  671169.354675
# 13     445110.982136  211261.5  207829.5  419091.0  55916.0  602435.982136
# ...              ...       ...       ...       ...      ...            ...
# 12224  439010.450951  192598.0  191468.0  384066.0  50991.0  582962.450951
# 12225  470204.587993  241856.5  240102.5  481959.0  57991.0  650340.587993
# 12226  526488.279535  246891.0  239864.0  486755.0  63323.0  709839.279535
# 12227  516248.149290  236375.0  243449.0  479824.0  52932.0  675785.149290
# 12228  391223.578995  191103.5  189060.5  380164.0  50745.0  555121.578995
#
#          ST155SV         update_stamp
# 0       874725.0  2024-12-02 08:27:54
# 6      1088080.0  2024-12-02 08:27:54
# 8      1040202.0  2024-12-02 08:27:54
# 12     1052429.0  2024-12-02 08:27:54
# 13      969703.0  2024-12-02 08:27:54
# ...          ...                  ...
# 12224   910066.0  2026-01-16 12:03:30
# 12225  1050096.0  2026-01-16 12:03:30
# 12226  1117553.0  2026-01-16 12:03:30
# 12227  1068338.0  2026-01-16 12:03:30
# 12228   871011.0  2026-01-16 12:03:30
#
# [3411 rows x 347 columns]

# %%
table.VISCODE.value_counts()
# Out:
# VISCODE
# sc        769
# 4_sc      640
# y2        459
# y1        385
# 4_init    333
# init      318
# y4        215
# 4_m12     155
# y3         96
# y5         24
# 4_m24      17
# Name: count, dtype: int64

# %%
getyear_dict = {
    "sc":-1,
    "4_sc":-1,
    "y2":2,
    "y1":1,
    "init":0,
    "4_init":0,
    "y4":4,
    "4_m12":1,
    "y3":3,
    "y5":5,
    "4_m24":2,
}

def getyear(x):
    return getyear_dict[x]

# %%
table = table.copy()
table["year"] = table.VISCODE.map(getyear)

# %%
ma = table.merge(diagnosis,on=["PTID","VISCODE"])

# %%
ma.isna().sum().sort_values()[-50:]
# drop those columns with too many null values. Those columns most likely do not contain valuable information.
# Out:
# ST35TS                   361
# ST48SA                   361
# ST48CV                   361
# ST48TS                   361
# ST48TA                   361
# ST38SA                   361
# ST38TS                   361
# ST38TA                   361
# ST35SA                   361
# ST97TA                   361
# ST107SA                  361
# DXMDUE                  2161
# DXMDES                  2165
# DXMPTR6                 2167
# DXMPTR4                 2167
# DXMPTR1                 2167
# DXMPTR3                 2170
# DXMPTR5                 2171
# DXMPTR2                 2172
# HAS_QC_ERROR            2259
# LANGUAGE_CODE           2259
# DD_CRF_VERSION_LABEL    2259
# CWMQC                   2261
# BGQC                    2261
# FRONTQC                 2261
# OVERALLQC               2261
# PARQC                   2261
# TEMPQC                  2261
# OCCQC                   2261
# INSULAQC                2261
# HIPPOQC                 2261
# VENTQC                  2261
# DXDSEV                  3015
# DXDDUE                  3015
# DXAPP                   3063
# ST68SV                  3115
# DXMOTHET                3255
# ST8SV                   3361
# DXAPOSS                 3378
# DXODES                  3385
# DXCONFID                3402
# DXPDES                  3402
# DXPATYP                 3402
# DXOTHDEM                3402
# DXPCOG                  3402
# DXNODEP                 3402
# DXAPROB                 3402
# DXAD                    3402
# DXNORM                  3402
# DXMCI                   3402
# dtype: int64

# %%
ma = ma.dropna(axis=1,thresh=len(ma)-1000)
# ma = ma.drop(["RID_x","RID_y","IMAGEUID"],axis=1)
ma
# Out:
#      PHASE_x         PTID  RID_x VISCODE VISCODE2_x  IMAGEUID FIELD_STRENGTH  \
# 0      ADNI3   002_S_4213   4213    init        m72    888008             3T
# 1      ADNI3   041_S_5253   5253      y4       m102   1576293             3T
# 2      ADNI3   035_S_6480   6480      y1        m12   1194953             3T
# 3      ADNI4   941_S_6471   6471   4_m12        m72  10932490             3T
# 4      ADNI3   168_S_6086   6086      sc         sc    917090             3T
# ...      ...          ...    ...     ...        ...       ...            ...
# 3397   ADNI4   941_S_7074   7074   4_m24        m42  11455284             3T
# 3398   ADNI4   006_S_6243   6243   4_m24        m90  11494945             3T
# 3399   ADNI4  389_S_10070  10070   4_m12        m18  11488775             3T
# 3400   ADNI4  073_S_10006  10006   4_m24        m24  11468696             3T
# 3401   ADNI4   027_S_6961   6961   4_m12        m54  11466310             3T
#
#       EXAMDATE_x     RUNDATE    STATUS  ... VISCODE2_y  EXAMDATE_y  DIAGNOSIS  \
# 0     2017-08-14  2022-07-23   partial  ...        m72  2017-08-10        1.0
# 1     2022-04-05  2022-09-30   partial  ...       m102  2022-03-28        2.0
# 2     2019-07-31  2024-11-19   partial  ...        m12  2019-08-06        2.0
# 3     2024-08-27  2024-10-16  complete  ...        m72  2024-09-03        1.0
# 4     2017-10-13  2022-07-26   partial  ...         sc  2017-10-20        1.0
# ...          ...         ...       ...  ...        ...         ...        ...
# 3397  2025-10-01  2025-10-31  complete  ...        m42  2025-09-09        1.0
# 3398  2025-11-19  2026-01-06  complete  ...        m90  2026-01-13        1.0
# 3399  2025-11-14  2026-01-06  complete  ...        m18  2025-12-15        2.0
# 3400  2025-10-13  2026-01-05  complete  ...        m24  2025-10-02        1.0
# 3401  2025-10-15  2026-01-06  complete  ...        m54  2025-10-14        2.0
#
#       DXPARK  DXDEP      ID  SITEID   USERDATE   USERDATE2  \
# 0        0.0    0.0   10647       1 2017-08-18  2017-08-18
# 1        0.0    0.0  156076      28 2022-05-05  2022-05-05
# 2        0.0    0.0   92304      25 2019-08-07  2019-08-07
# 3        0.0    0.0   31696     941 2024-09-03  2024-09-03
# 4        0.0    0.0   17412      58 2017-10-20  2017-10-20
# ...      ...    ...     ...     ...        ...         ...
# 3397     0.0    0.0  120009     941 2025-09-11  2025-09-11
# 3398     0.0    0.0  133591       6 2026-01-13  2026-01-13
# 3399     0.0    0.0  132693     389 2025-12-23  2025-12-23
# 3400     0.0    0.0  124255      73 2025-10-09  2025-10-09
# 3401     0.0    1.0  124888      27 2025-10-16  2025-10-16
#
#            update_stamp_y
# 0     2017-08-17 22:44:55
# 1     2022-05-06 04:18:11
# 2     2019-08-08 04:15:41
# 3     2024-09-04 01:49:51
# 4     2017-10-20 22:28:07
# ...                   ...
# 3397  2025-09-12 01:53:05
# 3398  2026-01-14 00:56:57
# 3399  2025-12-24 00:58:05
# 3400  2025-10-10 01:51:58
# 3401  2025-10-17 01:53:10
#
# [3402 rows x 348 columns]

# %%
ma_num = ma.select_dtypes(include=['number'])
ma_num.year
# Out:
# 0       0
# 1       4
# 2       1
# 3       1
# 4      -1
#        ..
# 3397    2
# 3398    2
# 3399    1
# 3400    2
# 3401    1
# Name: year, Length: 3402, dtype: int64

# %%
ma_num.corrwith(ma_num.year).sort_values()[:20]
# Out:
# RID_x      -0.436428
# RID_y      -0.436428
# IMAGEUID   -0.299388
# ST51TA     -0.134324
# SITEID     -0.128522
# ST58TA     -0.126818
# ST110TA    -0.115255
# ST117TA    -0.110695
# ST15TA     -0.102330
# ST18SV     -0.101996
# ST59TA     -0.101017
# ST118TA    -0.099480
# ST61SV     -0.098384
# ST74TA     -0.097948
# ST31TA     -0.096199
# ST120SV    -0.094680
# ST104TA    -0.093910
# ST12SV     -0.093599
# ST90TA     -0.091636
# ST56TA     -0.091516
# dtype: float64

# %%
ma_num.corrwith(ma_num.DIAGNOSIS).sort_values()[-20:]
# Out:
# ST46TS       0.167563
# ST115TS      0.167883
# ST74TS       0.170246
# ST13TS       0.171485
# ST47TS       0.176170
# ST128SV      0.179870
# ST15TS       0.180472
# ST26TS       0.185527
# ST55TS       0.192400
# ST56TS       0.193962
# ST80SV       0.208186
# ST54TS       0.218356
# ST21SV       0.237157
# ST7SV        0.244265
# ST96SV       0.273717
# ST127SV      0.276297
# ST37SV       0.291046
# ST30SV       0.397657
# ST89SV       0.408526
# DIAGNOSIS    1.000000
# dtype: float64

# %%
import pandas as pd


# Run the function
anova_summary_diagnosis = run_batch_anova(ma_num, 'DIAGNOSIS')

# View the top 10 most significant features
print(anova_summary_diagnosis.head(50))
# Out:
#     Feature  F-Statistic        P-Value
# 0    ST29SV   390.793714  8.616958e-153
# 1    ST89SV   371.621136  1.499957e-146
# 2    ST24TA   364.975567  1.214998e-143
# 3    ST30SV   353.825031  3.421093e-140
# 4    ST83TA   333.706507  1.752859e-132
# 5    ST88SV   322.788393  1.406539e-128
# 6    ST12SV   292.366974  1.931667e-117
# 7    ST58TA   272.146773  8.934420e-110
# 8    ST40TA   264.700604  5.191482e-107
# 9    ST90TA   220.376535   2.183778e-90
# 10   ST31TA   219.694008   3.978881e-90
# 11  ST117TA   210.940415   1.023295e-86
# 12   ST71SV   210.072833   1.678326e-86
# 13   ST26TA   201.896640   4.373985e-83
# 14   ST59TA   196.425589   3.478623e-81
# 15   ST99TA   196.474264   3.759269e-81
# 16   ST70SV   194.088377   1.616673e-80
# 17   ST52TA   190.364663   4.577289e-79
# 18   ST85TA   181.185464   4.311855e-75
# 19   ST11SV   179.246785   1.030321e-74
# 20  ST111TA   177.555406   4.757434e-74
# 21  ST118TA   170.291934   5.288985e-71
# 22  ST130TA   167.967189   2.915190e-70
# 23   ST40CV   162.965179   4.385651e-68
# 24   ST37SV   159.930672   4.454430e-67
# 25   ST32TA   153.265131   2.961401e-64
# 26   ST91TA   148.720918   1.874458e-62
# 27   ST60TA   147.114851   8.140894e-62
# 28   ST99CV   144.979339   5.749621e-61
# 29   ST72TA   144.403646   6.650464e-61
# 30   ST24CV   143.561585   1.851849e-60
# 31   ST96SV   139.578442   5.825259e-59
# 32  ST127SV   139.200668   8.257113e-59
# 33  ST119TA   139.456864   9.119414e-59
# 34  ST153SV   137.850448   2.814926e-58
# 35   ST57TA   137.647938   4.521368e-58
# 36  ST116TA   137.384378   5.763222e-58
# 37   ST83CV   136.744754   9.782682e-58
# 38  ST147SV   135.314459   2.940737e-57
# 39   ST58CV   130.127776   4.932548e-55
# 40   ST26CV   129.242863   1.307219e-54
# 41   ST32CV   129.044555   1.342299e-54
# 42   ST44TA   128.208870   2.611185e-54
# 43  ST149SV   123.552617   1.633383e-52
# 44  ST129TA   121.704335   9.260096e-52
# 45   ST15TA   120.892861   2.247026e-51
# 46   ST90CV   119.784625   6.841194e-51
# 47   ST31CV   116.876608   1.025703e-49
# 48   ST13TA   115.641850   2.639805e-49
# 49  ST103TA   113.396307   2.527551e-48

# %%
anova_summary_year = run_batch_anova(ma_num, 'year')
print(anova_summary_year.head(50))
# Out:
#       Feature  F-Statistic       P-Value
# 0       RID_x   368.892597  0.000000e+00
# 1          ID   544.624082  0.000000e+00
# 2       RID_y   368.892597  0.000000e+00
# 3    IMAGEUID    76.455555  7.601628e-90
# 4   DIAGNOSIS    39.926200  3.467690e-47
# 5      ST98TS    31.755819  2.552206e-37
# 6     ST113TS    29.935799  3.713237e-35
# 7     ST127SV    28.390781  2.778590e-33
# 8      ST54TS    27.470684  3.593820e-32
# 9     ST129TS    26.091249  1.702625e-30
# 10     ST96SV    25.977829  2.342107e-30
# 11     ST39TS    25.711867  5.176994e-30
# 12    ST115TS    25.511148  9.065860e-30
# 13    ST114TS    25.257564  1.840270e-29
# 14     ST89SV    24.676824  8.897968e-29
# 15     ST91TS    24.707157  8.984443e-29
# 16     ST37SV    24.476138  1.559848e-28
# 17     ST32TS    24.302075  2.781438e-28
# 18     ST36TS    23.732410  1.242743e-27
# 19     ST56TS    23.231291  5.291864e-27
# 20     ST30SV    22.450265  4.524554e-26
# 21     ST95TS    21.925703  1.956538e-25
# 22     ST55TS    21.840658  2.585936e-25
# 23    ST130TS    21.332066  1.035421e-24
# 24     ST84TS    20.306253  1.893379e-23
# 25     ST25TS    20.278168  2.048201e-23
# 26     ST26TS    20.112059  3.482404e-23
# 27     ST40TS    19.978011  4.897128e-23
# 28     ST51TA    18.768762  1.399748e-21
# 29    ST105TS    18.019814  1.107514e-20
# 30     ST99TS    18.028391  1.140414e-20
# 31     ST21SV    17.972478  1.268597e-20
# 32     ST46TS    17.708384  2.649919e-20
# 33     ST52TS    17.641927  3.192109e-20
# 34     ST58TA    17.510946  4.844248e-20
# 35     ST74TS    16.972364  2.133369e-19
# 36     ST80SV    16.810768  3.282277e-19
# 37     ST73TS    15.374318  1.822496e-17
# 38    ST118TS    14.623778  1.528175e-16
# 39     ST15TS    14.409545  2.749531e-16
# 40    ST117TA    13.950291  1.005175e-15
# 41     ST85TS    13.915156  1.126374e-15
# 42     ST12SV    13.788250  1.561653e-15
# 43    ST110TA    13.750895  1.726160e-15
# 44    ST104TS    13.503974  3.383163e-15
# 45     ST47TS    13.325668  5.562085e-15
# 46    ST106TS    13.110374  1.013538e-14
# 47     ST59TA    13.039406  1.263272e-14
# 48    ST113TA    13.004555  1.361080e-14
# 49    ST128SV    12.909857  1.771928e-14

# %%
anova_summary_cross = run_batch_anova(ma_num[["year","DIAGNOSIS"]], 'DIAGNOSIS')
anova_summary_cross
# Out:
#   Feature  F-Statistic   P-Value
# 0    year     0.400264  0.670175

# %%
import seaborn as sns

# %%
plot_diagnosis_distribution(ma_num, 'ST24TA')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
plot_patient_progression(table, 'ST24TA')

# %%
my_patients = list(patients.PTID.unique())

# %%
import random
cn_patients = random.choices(list(cn.PTID.unique()),k=50)
mci_patients = random.choices(list(mci.PTID.unique()),k=50)
ad_patients = random.choices(list(ad.PTID.unique()),k=50)

# %%
plot_specific_patients(table, 'ST24TA', cn_patients)
